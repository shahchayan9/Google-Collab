# %% [markdown]
# <a href="https://colab.research.google.com/github/shahchayan9/Google-Collab/blob/main/Assignment_1%2C_Chayan_Shah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of Python

# %%
print("Hello")
# Out:
# Hello

# %%
name='chayan'
print(name)
# Out:
# chayan

# %%
print(3/2)
# Out:
# 1.5

# %%
print(3**4)
# Out:
# 81

# %%
print(8*7)
# Out:
# 56

# %%
test1="Hi, I am Chayan Shah, "

# %%
test2="pursuing my Master's from SJSU"

# %%
print(test1+test2)
# Out:
# Hi, I am Chayan Shah, pursuing my Master's from SJSU

# %%
print('\n' *4)
print("after 4 lines")
# Out:
# after 4 lines

# %% [markdown]
# # List

# %%
subjects = ['Data Mining','Algorithms','Data Structures']
print(subjects[0])
# Out:
# Data Mining

# %%
print(subjects)
# Out:
# ['Data Mining', 'Algorithms', 'Data Structures']

# %%
subjects2 = ['OOPs','System Design']
combo=[subjects,subjects2]

# %%
print(combo)
# Out:
# [['Data Mining', 'Algorithms', 'Data Structures'], ['OOPs', 'System Design']]

# %%
print(combo[0][1])
# Out:
# Algorithms

# %%
subjects.append('DBMS')
print(subjects)
# Out:
# ['Data Mining', 'Algorithms', 'Data Structures', 'DBMS']

# %%
subjects.insert(1,'Development')
print(subjects)
# Out:
# ['Data Mining', 'Development', 'Algorithms', 'Data Structures', 'DBMS']

# %%
subjects.remove('Development')

# %%
print(subjects)
# Out:
# ['Data Mining', 'Algorithms', 'Data Structures', 'DBMS']

# %%
subjects.sort()
print(subjects)
# Out:
# ['Algorithms', 'DBMS', 'Data Mining', 'Data Structures']

# %%
del subjects[1]

# %%
print(subjects)
# Out:
# ['Algorithms', 'Data Mining', 'Data Structures']

# %%
print(len(subjects))
# Out:
# 3

# %% [markdown]
# # Tuple

# %%
temp_tuple = (1,2,3,4)
print(temp_tuple)
# Out:
# (1, 2, 3, 4)

# %%
print(list(temp_tuple))
# Out:
# [1, 2, 3, 4]

# %%
len(temp_tuple)
# Out:
# 4

# %%
print(len(temp_tuple))
# Out:
# 4

# %% [markdown]
# # Dict

# %%
temp_dict = {1:'A',2:'B'}
print(temp_dict[2])
# Out:
# B

# %%
del temp_dict[2]

# %%
print(temp_dict)
# Out:
# {1: 'A'}

# %%
len(temp_dict)
# Out:
# 1

# %%
print(temp_dict.keys())
# Out:
# dict_keys([1])

# %% [markdown]
# # Conditional Statements

# %%
age=22
gender='M'

if age>20 and gender=='M':
  print('male child')
else:
  print('adult')
# Out:
# male child

# %% [markdown]
# # Looping

# %%
for x in range(1,10):
  print('hello', x)
  print('\n')
# Out:
# hello 1
#
#
# hello 2
#
#
# hello 3
#
#
# hello 4
#
#
# hello 5
#
#
# hello 6
#
#
# hello 7
#
#
# hello 8
#
#
# hello 9

# %%
for i in subjects:
  print(i)
# Out:
# Algorithms
# Data Mining
# Data Structures

# %%
import random
r=random.randrange(1,10)
print(r)
# Out:
# 1

# %% [markdown]
# # Functions

# %%
def add(x,y):
  return x+y

# %%
add(4,5)
# Out:
# 9

# %% [markdown]
# # Input

# %%
import sys
name=sys.stdin.readline()
print(name)

# %% [markdown]
# # File

# %%
test_file=open("text.txt","wb")
print(test_file.mode)
print(test_file.name)
test_file.close()
# Out:
# wb
# text.txt

# %% [markdown]
# # Class

# %%
class Animals:
  def __init__(self,name,age):
    self.name=name
    self.age=age

# %%
# %%html
# <h1>Heading 1</h1>
# Out:
# <h1>Heading 1</h1>

# %% [markdown]
# # Elastic Magic

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# x <- 42
# print(x)
# Out:
# [1] 42

# %% [markdown]
# # Magic

# %% [markdown]
# Drawing with [svg.js notebook](https://colab.research.google.com/drive/1sMN6UePrk6P5zZqsyBXHY7XqX0T9Aw_5)

# %%
import re
from IPython.display import HTML
from IPython.core.magic import register_cell_magic

# %%
import re

def var_sub(m, context=None):
    context = context or globals()
    var_name = m.group(1)

    # Handle nested attributes or dictionary keys
    parts = var_name.split('.')

    try:
        v = context[parts[0]]
        for part in parts[1:]:
            if isinstance(v, dict):
                v = v[part]
            else:
                v = getattr(v, part)

    except (KeyError, AttributeError) as e:
        return f"<undefined: {var_name}>"

    # Return string representation of the variable
    return str(v)

# Example usage in a regular expression substitution
example_string = "Hello, {name}!"
name = "Chayan"
pattern = re.compile(r'\{(\w+)\}')
result = pattern.sub(var_sub, example_string)
print(result)  # Output: Hello, Chayan!
# Out:
# Hello, Chayan!

# %%
@register_cell_magic
def javascript(line="", cell=""):
  # var sub
  cell = re.sub(r'\{\{(\w+)+}}', var_sub, cell)

  m = re.match(r'\w+', line)
  if m:
    globals()[m[0]] = cell
  else:
    display(HTML("""
<div id="drawing"></div>
<script src="https://cdnjs.cloudflare.com/ajax/libs/svg.js/2.6.5/svg.js"></script>
<script>
var draw = SVG('drawing').size('100%', 100)
var y_cursor_pos = 0
function print(x){
  draw.text(x.toString()).move(400, y_cursor_pos)
  y_cursor_pos += 20
}

text = s=> draw.text(s).font('anchor', 'middle')
line = (x1,y1, x2,y2)=> draw.line(x1,y1, x2, y2).stroke({width: 1})
max = Math.max
""" + cell))

# %%
# %%javascript
#
# draw.rect(100, 70)
# Out:
# <div id="drawing"></div>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/svg.js/2.6.5/svg.js"></script>
# <script>
# var draw = SVG('drawing').size('100%', 100)
# var y_cursor_pos = 0
# function print(x){
#   draw.text(x.toString()).move(400, y_cursor_pos)
#   y_cursor_pos += 20
# }
#
# text = s=> draw.text(s).font('anchor', 'middle')
# line = (x1,y1, x2,y2)=> draw.line(x1,y1, x2, y2).stroke({width: 1})
# max = Math.max
#
# draw.rect(100, 70)

# %% [markdown]
# # Elastic search magic

# %%
# install
# !wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.0.0-linux-x86_64.tar.gz -q
# !tar -xzf elasticsearch-7.0.0-linux-x86_64.tar.gz
# !chown -R daemon:daemon elasticsearch-7.0.0

# %%
# start server
import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-8.15.1/bin/elasticsearch'],
                  stdout=PIPE, stderr=STDOUT,
                  preexec_fn=lambda: os.setuid(1)  # as daemon
                 )

# %%
# wait a bit then test
# !curl -X GET "localhost:9200/"
# Out:
# curl: (7) Failed to connect to localhost port 9200: Connection refused

# %%
from requests import models, Session, Request
from urllib.parse import urljoin
from IPython.core.magic import register_cell_magic
import re

# to display json response
def render(r):
  text = r.text
  if text[0] in "[{":  # really json
    return """
    <script src="https://rawgit.com/caldwell/renderjson/master/renderjson.js"></script>
    <script>
    renderjson.set_show_to_level(1)
    document.body.appendChild(renderjson(%s))
    new ResizeObserver(google.colab.output.resizeIframeToContent).observe(document.body)
    </script>
    """ % text
  else:    # other status text
    return "<pre>%s</pre>" % text
models.Response._repr_html_ = render

# %%
# %%es magic
@register_cell_magic
def es(line=None, cell=""):
  cell = re.sub(r'(?m)^\s*#.*\n?','', cell) # remove comment
  line1 = (cell + '\n').find('\n')
  method, path = cell[:line1].split(None, 1)
  body = cell[line1:].strip()
  args = {}
  if body:
    args['data'] = (body + '\n').encode()  # in case _bulk
    args['headers'] = {'Content-Type': 'application/json'}

  rsp = Session().send(
          Request(method, urljoin('http://localhost:9200', path), **args)
            .prepare())
  return rsp

# %%
# %%es
# PUT /customer/_doc/1
# {
#   "name": "John Doe"
# }

# %%
# %%es
# PUT customer/_doc/2
# {
#   "name": "John Smith"
# }

# %% [markdown]
# # Python calls JS

# %% [markdown]
# 3 methods

# %%
# %%html
# <script>
# document.body.append(document.createTextNode("Hello"))
# </script>
# Out:
# <script>
# document.body.append(document.createTextNode("Hello"))
# </script>

# %%
from IPython.display import Javascript
Javascript('document.body.append(document.createTextNode("Hello"))')

# %% [markdown]
# Only this last one returns something back to python

# %%
from google.colab.output import eval_js
eval_js('1+1')
# Out:
# 2

# %% [markdown]
# # JS calls Python

# %% [markdown]
# # Toy Example

# %%
from IPython.display import JSON
import IPython.display as idisplay
from google.colab import output

def concat(a, b):
  return JSON({'result': '%s %s' % (a, b)})

output.register_callback('notebook.concat', concat)

# %%
idisplay.Javascript('''
(async function() {

  const result = await google.colab.kernel.invokeFunction(
    'notebook.concat',
    ['hello', 'world!'],
    {});

  const text = result.data['application/json'].result;

  document.querySelector("#output-area").appendChild(document.createTextNode(text))

})();
''')

# %% [markdown]
# # Take a photo

# %% [markdown]
# Use eval_js because there's only 1 action to save data

# %%
from IPython.display import HTML, Image
from google.colab.output import eval_js
from base64 import b64decode

# %%
VIDEO_HTML = """
<video autoplay
 width=800 height=600></video>
<script>
var video = document.querySelector('video')
navigator.mediaDevices.getUserMedia({ video: true })
  .then(stream=> video.srcObject = stream)

var data = new Promise(resolve=>{
  video.onclick = ()=>{
    var canvas = document.createElement('canvas')
    var [w,h] = [video.offsetWidth, video.offsetHeight]
    canvas.width = w
    canvas.height = h
    canvas.getContext('2d')
          .drawImage(video, 0, 0, w, h)
    video.srcObject.getVideoTracks()[0].stop()
    video.replaceWith(canvas)
    resolve(canvas.toDataURL('image/jpeg', %f))
  }
})
</script>
"""

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  display(HTML(VIDEO_HTML % quality))
  data = eval_js("data")
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return len(binary)

# %%
take_photo()
# Out:
# <video autoplay
#  width=800 height=600></video>
# <script>
# var video = document.querySelector('video')
# navigator.mediaDevices.getUserMedia({ video: true })
#   .then(stream=> video.srcObject = stream)
#
# var data = new Promise(resolve=>{
#   video.onclick = ()=>{
#     var canvas = document.createElement('canvas')
#     var [w,h] = [video.offsetWidth, video.offsetHeight]
#     canvas.width = w
#     canvas.height = h
#     canvas.getContext('2d')
#           .drawImage(video, 0, 0, w, h)
#     video.srcObject.getVideoTracks()[0].stop()
#     video.replaceWith(canvas)
#     resolve(canvas.toDataURL('image/jpeg', 0.800000))
#   }
# })
# </script>

# %% [markdown]
# # Zip File

# %%
# !wget -0  https://www.learningcontainer.com/wp-content/uploads/2020/05/sample-zip-file.zip
# Out:
# wget: invalid option -- '0'
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.

# %%
# prompt: correct just above code

# !wget -O sample-zip-file.zip https://www.learningcontainer.com/wp-content/uploads/2020/05/sample-zip-file.zip
# Out:
# --2024-09-08 22:28:22--  https://www.learningcontainer.com/wp-content/uploads/2020/05/sample-zip-file.zip
# Resolving www.learningcontainer.com (www.learningcontainer.com)... 172.67.188.164, 104.21.84.74, 2606:4700:3033::ac43:bca4, ...
# Connecting to www.learningcontainer.com (www.learningcontainer.com)|172.67.188.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 380 [application/zip]
# Saving to: ‘sample-zip-file.zip’
#
# sample-zip-file.zip 100%[===================>]     380  --.-KB/s    in 0s
#
# 2024-09-08 22:28:22 (194 MB/s) - ‘sample-zip-file.zip’ saved [380/380]

# %%
# prompt: unzip just above file and unzip to current directory

# !unzip sample-zip-file.zip
# Out:
# Archive:  sample-zip-file.zip
# replace sample.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# # Drive

# %%
# connect to google drive with mount
from google.colab import drive
drive.mount('mount')
# Out:
# Mounted at mount

# %%
# copy a file there to here
# !cp mount/My\ Drive/kaggle.json  .

# %%
# download a public file
# !gdown  --id  0B7EVK8r0v71pZjFTYXZWM3FlRnM
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
# From (redirected): https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM&confirm=t&uuid=cb3df1ab-2f92-4b2c-a505-804af44f811b
# To: /content/img_align_celeba.zip
# 100% 1.44G/1.44G [00:28<00:00, 50.2MB/s]

# %%
# !ls -al *.zip
# Out:
# -rw-r--r-- 1 root root 1443490838 Sep  8 22:37 img_align_celeba.zip
# -rw-r--r-- 1 root root    5216156 Sep 12  2020 sample-large-zip-file.zip
# -rw-r--r-- 1 root root        380 Sep 12  2020 sample-zip-file.zip

# %%
# authenticate (another one)
from google.colab import auth
auth.authenticate_user()

# %%
# I want to download this folder
folder_id="1HvIeNhqtFVllXFWzH5NawDdnIfgGDwCK"

# %%
'''list all ids of files directly under folder folder_id'''
def folder_list(folder_id):
  from googleapiclient.discovery import build
  gdrive = build('drive', 'v3').files()
  res = gdrive.list(q="'%s' in parents" % folder_id).execute()
  return [f['id'] for f in res['files']]

# %%
folder_list(folder_id)
# Out:
# ['1MJGCY0uhkwxoBpSXAYWk6WKHUAYMxGlQ',
#  '1KgSEm4A7hCov2Ta6-CZldqT-9JgtiVRI',
#  '16wxQwBvzMUTK5PYdakkaVFV-F38vi7RK',
#  '1LuB1aplL2cl-Hs_BFdZgPoDcCnNsGJBa',
#  '11mzTo7aWTeCs4TSPqKQKbYDl9xIxBISQ',
#  '1VgAS5dGP2ub4G_PJ_4YwEXjEiDhqyiyt',
#  '17duniZO_R7p3eTIkMzSRbNpHdQjonAMQ',
#  '12oSVL5pFxe-DqVk5GWjBYHxbi9gGGYha',
#  '1QKUWh62qzaOIBebJY0IkcAxqHCEaeYo1',
#  '1QEMMVAAsA93qrlXhVxjFH4wbLiU6R6Ds',
#  '18SYApxloSMwaSgnOILkOm7FjOVaFH6DH',
#  '1jAg2oODTyVZvHvDwEdQhmxsnQWG-cbLH',
#  '1toORa_XzdSj4UNMYSyeVmEgEniMot9PJ',
#  '1aHDIvbB6MKZTxIfZgAeU8WzN6JIsGrPa']

# %%
# download them one by one, notice  !gdown in the loop
def folder_download(folder_id):
  for fid in folder_list(folder_id):
    # !gdown -q --id $fid

# %% [markdown]
# # Anaconda

# %%
# !wget -c https://repo.anaconda.com/archive/Anaconda3-2020.07-Linux-x86_64.sh
# !chmod +x Anaconda3-2020.07-Linux-x86_64.sh
# !bash ./Anaconda3-2020.07-Linux-x86_64.sh -b -f -p /usr/local

# Installs the pytorch and faiss-cpu library from conda
# !conda install -q -y --prefix /usr/local -c pytorch faiss-cpu
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages/')
import faiss
# Out:
# Streaming output truncated to the last 5000 lines.
# lxml==4.5.2=py38hefd8a0e_0 -> python[version='>=3.8,<3.9.0a0']
# cycler==0.10.0=py38_0 -> six -> python[version='>=3.6,<3.7.0a0']
# anaconda==2020.07=py38_0 -> python==3.8.3=hcff3b4d_2
# traitlets==4.3.3=py38_0 -> decorator -> python[version='>=3.5|>=3.6,<3.7.0a0']
# contextlib2==0.6.0.post1=py_0 -> python
# zope.event==4.4=py38_0 -> python[version='>=3.8,<3.9.0a0']
# heapdict==1.0.1=py_0 -> python
# numpydoc==1.1.0=py_0 -> sphinx -> python[version='>=3.10,<3.11.0a0|>=3.5|>=3.6,<3.7.0a0|>=3.9,<3.10.0a0']
# pytz==2020.1=py_0 -> python
# navigator-updater==0.2.1=py38_0 -> pyqt[version='>=5.6'] -> python[version='>=3.10,<3.11.0a0|>=3.6,<3.7.0a0|>=3.9,<3.10.0a0']
# pexpect==4.8.0=py38_0 -> ptyprocess[version='>=0.5'] -> python[version='>=3.6,<3.7.0a0']
# pyflakes==2.2.0=py_0 -> python
# requests==2.24.0=py_0 -> certifi[version='>=2017.4.17'] -> python[version='<4.0|>=3.10,<3.11.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.9,<3.10.0a0']
# ...
